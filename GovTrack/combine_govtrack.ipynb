# %%
import os
import glob
import pandas as pd

# %%
csvs = [x for x in os.listdir() if 'csv' in x]

# %%
csvs
# Out:
# ['congress_votes_116-2019_h134.csv',
#  'congress_votes_116-2019_h91.csv',
#  'congress_votes_116-2019_h118.csv',
#  'congress_votes_116-2019_h127.csv',
#  'congress_votes_116-2019_h156.csv',
#  'congress_votes_116-2019_h146.csv',
#  'congress_votes_116-2019_h153.csv',
#  'congress_votes_116-2019_h167.csv']

# %%
bill_names = ['Paycheck Fairness Act',  
              'Background Check for Firearms',
              'For the People Act 2019', 
              "Trump's National Emergency", 
              'Violence against Women Reauthorization Act', 
              'Health Care', 
              'Remove Troops from Yemen', 
              'Save the Internet']

# %%
dfs = []
for csv, bill in zip(csvs, bill_names):
    df = pd.read_csv(csv).reset_index()
    act_name = df.columns[-1]
    new_header = df.iloc[0] #grab the first row for the header
    df = df[1:] #take the data less the header row
    df.columns = new_header #set the header row as the df header
    df['Bill'] = [bill] * len(df)
    dfs.append(df)

# %%
combined = pd.concat(dfs)

# %%
politicians
# Out:
# ['earl blumenauer',
#  'daniel webster',
#  'john barrasso',
#  'louie gohmert',
#  'steve king',
#  'ted yoho',
#  'mitch mcconnell',
#  'maxine waters',
#  'terri sewell',
#  'mo brooks',
#  'juan vargas',
#  'marcy kaptur',
#  'jared huffman',
#  'elijah cummings',
#  'katherine clark',
#  'chuck grassley',
#  'paul gosar',
#  'michael mccaul',
#  'bill foster',
#  'barry loudermilk',
#  'pete king',
#  'steve stivers',
#  'ruben gallego',
#  'cheri bustos',
#  'john ratcliffe',
#  'jackie speier',
#  'david b mckinley',
#  'joni ernst',
#  'john yarmuth',
#  'bill huizenga',
#  'mark takano',
#  'val demings',
#  'john lewis',
#  'joe kennedy',
#  'seth moulton',
#  'kathy castor',
#  'ted lieu',
#  'brian babin',
#  'don beyer',
#  'adam kinzinger',
#  'derek kilmer',
#  'don bacon',
#  'stacey plaskett',
#  'tim ryan',
#  'stephanie murphy',
#  'john thune',
#  'kevin mccarthy',
#  'kevin brady',
#  'deb dingell',
#  'hakeem jeffries',
#  'marco rubio',
#  'pete olson',
#  'jerry nadler',
#  'dan kildee',
#  'tulsi gabbard',
#  'mario diaz-balart',
#  'ro khanna',
#  'bob latta',
#  'jeff duncan',
#  'peter welch',
#  'richard neal',
#  'brenda lawrence',
#  'joaquin castro',
#  'steve scalise',
#  'grace meng',
#  'lucille roybal-allard',
#  'scott peters',
#  'will hurd',
#  'annie kuster',
#  'mike enzi',
#  'jim jordan',
#  'sean maloney',
#  'bob gibbs',
#  'tom graves',
#  'rashida tlaib',
#  'rob porman',
#  'pramila jayapal',
#  'cathy rodgers',
#  'eric swalwell',
#  'mark green',
#  'barbra lee',
#  'scott tipton',
#  'debbie wasserman schultz',
#  'austin scott',
#  'bill johnson',
#  'nanette barragan',
#  'thomas massie',
#  'marc veasey',
#  'john shimkus',
#  'nancy pelosi',
#  'mark pocan',
#  'adam schiff',
#  'steny hoyer',
#  'jason smith',
#  'ilhan omar',
#  'alan lowenthal',
#  'diana degette',
#  'lucy mcbath',
#  'dan newhouse',
#  'suzanne bonamici',
#  'adrian smith',
#  'alexandria ocasio-cortez',
#  'elise stefanik',
#  'lee zeldin',
#  'karen bass',
#  'sean duffy',
#  'doug collins',
#  'robin kelly',
#  'john curtis',
#  'matt gaetz',
#  'john cornyn',
#  'clay higgens',
#  'mitt romney',
#  'chip roy',
#  'mark meadows',
#  'kay granger',
#  'devin nunes']

# %%
def standardize_names(name):
    name = name.lower()
    name = name.split(" [")[0]
    name = name.split("rep. ")[1]
    return name

# %%
combined['name'] = combined['name'].apply(standardize_names)

# %%
df = combined[combined['name'].isin(politicians)]

# %%
df['party'] = df['party'].apply(lambda x: x[0])
# Out:
# /Users/alexluo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['vote'].unique()
# Out:
# array(['Yea', 'Nay', 'Not Voting', 'Aye', 'No'], dtype=object)

# %%
0 == (0 or 2)
# Out:
# False

# %%
df['vote'] = df['vote'].apply(lambda x: 1 if (x == 'Yea' or x == 'Aye') else 0 if (x == 'Nay' or x == 'No') else -1)
# Out:
# /Users/alexluo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df = df.drop('district', axis = 1)
df = df.drop('person', axis = 1)

# %%
df.to_csv('govtrack.csv', index = False)

# %%
# Out:
#                           state  vote  party  Bill
# name
# adam kinzinger                8     8      8     8
# adam schiff                   8     8      8     8
# adrian smith                  8     8      8     8
# alan lowenthal                8     8      8     8
# alexandria ocasio-cortez      8     8      8     8
# austin scott                  8     8      8     8
# barry loudermilk              8     8      8     8
# bill foster                   8     8      8     8
# bill huizenga                 8     8      8     8
# bill johnson                  8     8      8     8
# bob gibbs                     8     8      8     8
# brenda lawrence               8     8      8     8
# brian babin                   8     8      8     8
# cheri bustos                  8     8      8     8
# chip roy                      8     8      8     8
# dan newhouse                  8     8      8     8
# daniel webster                8     8      8     8
# debbie wasserman schultz      8     8      8     8
# derek kilmer                  8     8      8     8
# devin nunes                   8     8      8     8
# diana degette                 8     8      8     8
# don bacon                     8     8      8     8
# doug collins                  8     8      8     8
# earl blumenauer               8     8      8     8
# elijah cummings               8     8      8     8
# elise stefanik                8     8      8     8
# eric swalwell                 8     8      8     8
# grace meng                    8     8      8     8
# hakeem jeffries               8     8      8     8
# ilhan omar                    8     8      8     8
# ...                         ...   ...    ...   ...
# nancy pelosi                  6     6      6     6
# paul gosar                    8     8      8     8
# pete olson                    8     8      8     8
# peter welch                   8     8      8     8
# pramila jayapal               8     8      8     8
# rashida tlaib                 8     8      8     8
# richard neal                  8     8      8     8
# ro khanna                     8     8      8     8
# robin kelly                   8     8      8     8
# ruben gallego                 8     8      8     8
# scott peters                  8     8      8     8
# scott tipton                  8     8      8     8
# sean duffy                    8     8      8     8
# sean maloney                  8     8      8     8
# seth moulton                  8     8      8     8
# steny hoyer                   8     8      8     8
# stephanie murphy              8     8      8     8
# steve king                    8     8      8     8
# steve scalise                 8     8      8     8
# steve stivers                 8     8      8     8
# suzanne bonamici              8     8      8     8
# ted lieu                      8     8      8     8
# ted yoho                      8     8      8     8
# terri sewell                  8     8      8     8
# thomas massie                 8     8      8     8
# tim ryan                      8     8      8     8
# tom graves                    8     8      8     8
# tulsi gabbard                 8     8      8     8
# val demings                   8     8      8     8
# will hurd                     8     8      8     8
#
# [92 rows x 4 columns]
