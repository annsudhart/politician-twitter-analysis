# %%
import os
import glob
import pandas as pd

# %%
csvs = [x for x in os.listdir() if 'csv' in x]

# %%
csvs
# Out:
# ['congress_votes_116-2019_h134.csv',
#  'congress_votes_116-2019_h91.csv',
#  'congress_votes_116-2019_h118.csv',
#  'congress_votes_116-2019_h127.csv',
#  'congress_votes_116-2019_h156.csv',
#  'congress_votes_116-2019_h146.csv',
#  'congress_votes_116-2019_h153.csv',
#  'congress_votes_116-2019_h167.csv']

# %%
bill_names = ['Paycheck Fairness Act',  
              'Background Check for Firearms',
              'For the People Act 2019', 
              "Trump's National Emergency", 
              'Violence against Women Reauthorization Act', 
              'Health Care', 
              'Remove Troops from Yemen', 
              'Save the Internet']

# %%
dfs = []
for csv, bill in zip(csvs, bill_names):
    df = pd.read_csv(csv).reset_index()
    act_name = df.columns[-1]
    new_header = df.iloc[0] #grab the first row for the header
    df = df[1:] #take the data less the header row
    df.columns = new_header #set the header row as the df header
    df['Bill'] = [bill] * len(df)
    dfs.append(df)

# %%
combined = pd.concat(dfs)

# %%
politicians
# Out:
# ['earl blumenauer',
#  'daniel webster',
#  'john barrasso',
#  'louie gohmert',
#  'steve king',
#  'ted yoho',
#  'mitch mcconnell',
#  'maxine waters',
#  'terri sewell',
#  'mo brooks',
#  'juan vargas',
#  'marcy kaptur',
#  'jared huffman',
#  'elijah cummings',
#  'katherine clark',
#  'chuck grassley',
#  'paul gosar',
#  'michael mccaul',
#  'bill foster',
#  'barry loudermilk',
#  'pete king',
#  'steve stivers',
#  'ruben gallego',
#  'cheri bustos',
#  'john ratcliffe',
#  'jackie speier',
#  'david b mckinley',
#  'joni ernst',
#  'john yarmuth',
#  'bill huizenga',
#  'mark takano',
#  'val demings',
#  'john lewis',
#  'joe kennedy',
#  'seth moulton',
#  'kathy castor',
#  'ted lieu',
#  'brian babin',
#  'don beyer',
#  'adam kinzinger',
#  'derek kilmer',
#  'don bacon',
#  'stacey plaskett',
#  'tim ryan',
#  'stephanie murphy',
#  'john thune',
#  'kevin mccarthy',
#  'kevin brady',
#  'deb dingell',
#  'hakeem jeffries',
#  'marco rubio',
#  'pete olson',
# ...

# %%
def standardize_names(name):
    name = name.lower()
    name = name.split(" [")[0]
    name = name.split("rep. ")[1]
    return name

# %%
combined['name'] = combined['name'].apply(standardize_names)

# %%
df = combined[combined['name'].isin(politicians)]

# %%
df['party'] = df['party'].apply(lambda x: x[0])
# Out:
# /Users/alexluo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['vote'].unique()
# Out:
# array(['Yea', 'Nay', 'Not Voting', 'Aye', 'No'], dtype=object)

# %%
0 == (0 or 2)
# Out:
# False

# %%
df['vote'] = df['vote'].apply(lambda x: 1 if (x == 'Yea' or x == 'Aye') else 0 if (x == 'Nay' or x == 'No') else -1)
# Out:
# /Users/alexluo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df = df.drop('district', axis = 1)
df = df.drop('person', axis = 1)

# %%
df
# Out:
# 0   state  vote                      name party                   Bill
# 4      OR     1           earl blumenauer     D  Paycheck Fairness Act
# 5      TX     0               kevin brady     R  Paycheck Fairness Act
# 15     MD     1           elijah cummings     D  Paycheck Fairness Act
# 19     CO     1             diana degette     D  Paycheck Fairness Act
# 21     FL     1         mario diaz-balart     R  Paycheck Fairness Act
# 26     TX    -1               kay granger     R  Paycheck Fairness Act
# 30     MD     1               steny hoyer     D  Paycheck Fairness Act
# 33     OH     1              marcy kaptur     D  Paycheck Fairness Act
# 36     IA     0                steve king     R  Paycheck Fairness Act
# 41     GA     1                john lewis     D  Paycheck Fairness Act
# 52     MA     1              richard neal     D  Paycheck Fairness Act
# 53     CA     0               devin nunes     R  Paycheck Fairness Act
# ...

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames], sort = True)

# %%
combined_csv
# Out:
#                                                     2019.  United States Code  \
# (person, state, district, vote, name)                 NaN                 NaN
# (400004, AL, 4, Nay, Rep. Robert Aderholt [R])        NaN                 NaN
# (400029, UT, 1, Nay, Rep. Rob Bishop [R])             NaN                 NaN
# (400030, GA, 2, Yea, Rep. Sanford Bishop Jr. [D])     NaN                 NaN
# (400033, OR, 3, Yea, Rep. Earl Blumenauer [D])        NaN                 NaN
# (400046, TX, 8, Nay, Rep. Kevin Brady [R])            NaN                 NaN
# (400052, TX, 26, Nay, Rep. Michael Burgess [R])       NaN                 NaN
# (400057, CA, 42, Nay, Rep. Ken Calvert [R])           NaN                 NaN
# (400068, TX, 31, Nay, Rep. John Carter [R])           NaN                 NaN
# (400069, HI, 1, Yea, Rep. Ed Case [D])                NaN                 NaN
# (400071, OH, 1, Nay, Rep. Steve Chabot [R])           NaN                 NaN
# ...

# %%
tweets
